# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('seaborn-pastel')

# %%
df = pd.read_csv("owid-covid-data (1).csv")

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149028 entries, 0 to 149027
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    149028 non-null  object
#  1   continent                                   140034 non-null  object
#  2   location                                    149028 non-null  object
#  3   date                                        149028 non-null  object
#  4   total_cases                                 146418 non-null  float64
#  5   new_cases                                   146412 non-null  float64
#  6   new_cases_smoothed                          145267 non-null  float64
#  7   total_deaths                                129414 non-null  float64
#  8   new_deaths                                  129610 non-null  float64
# ...

# %%
columns = df.columns.tolist()
columns.remove('population')

# %%
columns.insert(4,'population')

# %%
df = df[columns]

# %%
df.head()
# Out:
#   iso_code continent     location        date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24  39835428.0          5.0
# 1      AFG      Asia  Afghanistan  2020-02-25  39835428.0          5.0
# 2      AFG      Asia  Afghanistan  2020-02-26  39835428.0          5.0
# 3      AFG      Asia  Afghanistan  2020-02-27  39835428.0          5.0
# 4      AFG      Asia  Afghanistan  2020-02-28  39835428.0          5.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        5.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# ...

# %%
deathData = df.loc[:, :'weekly_hosp_admissions_per_million']

# %%
vaccinationCols = columns[:4] + columns[columns.index('weekly_hosp_admissions_per_million')+1:]
vaccinationData = df[vaccinationCols]
vaccinationData.head()
# Out:
#   iso_code continent     location        date  new_tests  total_tests  \
# 0      AFG      Asia  Afghanistan  2020-02-24        NaN          NaN
# 1      AFG      Asia  Afghanistan  2020-02-25        NaN          NaN
# 2      AFG      Asia  Afghanistan  2020-02-26        NaN          NaN
# 3      AFG      Asia  Afghanistan  2020-02-27        NaN          NaN
# 4      AFG      Asia  Afghanistan  2020-02-28        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  ...  female_smokers  male_smokers  \
# ...

# %%
vaccinationData.to_csv("vaccination.csv")
deathData.to_csv("death.csv")

# %%
from sqlalchemy import create_engine
import MySQLdb
con  = create_engine("mysql+mysqldb://student:student@localhost/CovidData")

# %%
vaccinationData.to_sql(con=con, name='Vaccination', if_exists='replace')
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\pandas\io\sql.py:1423: UserWarning: The provided table name 'Vaccination' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
deathData.to_sql(con=con, name='Deaths', if_exists='replace')
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\pandas\io\sql.py:1423: UserWarning: The provided table name 'Deaths' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
